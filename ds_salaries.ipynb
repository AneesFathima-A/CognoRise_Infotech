# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Aneesfathima\OneDrive\Desktop\ds_salaries.csv")
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.shape
# Out:
# (607, 12)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
df.rename(columns={'Unnamed: 0':'s_no'}, inplace=True)

# %%
df.head()
# Out:
#    s_no  work_year experience_level employment_type  \
# 0     0       2020               MI              FT
# 1     1       2020               SE              FT
# 2     2       2020               SE              FT
# 3     3       2020               MI              FT
# 4     4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.nunique()
# Out:
# s_no                  607
# work_year               3
# experience_level        4
# employment_type         4
# job_title              50
# salary                272
# salary_currency        17
# salary_in_usd         369
# employee_residence     57
# remote_ratio            3
# company_location       50
# company_size            3
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df['salary_in_usd'], kde=True)
plt.show()
# Out:
# C:\Users\Aneesfathima\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.countplot(df, x='work_year')
plt.show()

# %%
sns.countplot(df, x='experience_level')
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.countplot(df, x='job_title')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(df, x='salary_currency')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.countplot(df, x='employee_residence')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(df, x='remote_ratio')
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.countplot(df, x='company_location')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(df, x='company_size')
plt.show()

# %%
sns.boxplot(data=df, x='experience_level', y='salary_in_usd')
plt.show()

# %%
import plotly.express as px

# %%
fig = px.box(df, x='job_title', y='salary_in_usd', color='job_title', width=1400, height=700)
fig.update_layout(xaxis = {'tickangle':270})
fig.show()

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(data=df, x='remote_ratio', y='salary_in_usd', hue='experience_level')
plt.show()

# %%
plt.figure(figsize=(14,7))
sns.scatterplot(data=df, x='job_title', y='salary_in_usd', palette='Set1', hue='remote_ratio')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.barplot(data=df, x='company_location', y='salary_in_usd')
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(data=df, x='company_size', y='salary_in_usd')
plt.show()

# %%
Avg_salary_for_jobs = pd.DataFrame(df.groupby(['job_title','experience_level'])['salary_in_usd'].mean())
Avg_salary_for_jobs.sort_values(by=['salary_in_usd'], ascending=False)
# Out:
#                                                            salary_in_usd
# job_title                                experience_level
# Principal Data Engineer                  EX                600000.000000
# Financial Data Analyst                   MI                450000.000000
# Principal Data Scientist                 EX                416000.000000
# Data Analytics Lead                      SE                405000.000000
# Applied Data Scientist                   SE                278500.000000
# ML Engineer                              SE                256000.000000
# Data Engineer                            EX                245500.000000
# Head of Data                             EX                232500.000000
# Machine Learning Scientist               EN                225000.000000
#                                          SE                201666.666667
# Data Science Manager                     MI                200000.000000
# ...

# %%
Avg_salary_for_jobs = pd.DataFrame(df.groupby(['job_title','company_size'])['salary_in_usd'].mean())
Avg_salary_for_jobs.sort_values(by=['salary_in_usd'], ascending=False)
# Out:
#                                                        salary_in_usd
# job_title                                company_size
# Principal Data Scientist                 S             416000.000000
# Data Analytics Lead                      L             405000.000000
# Principal Data Engineer                  L             392500.000000
# Lead Data Engineer                       L             276000.000000
# Financial Data Analyst                   L             275000.000000
# Applied Machine Learning Scientist       L             249000.000000
# Director of Data Science                 L             213498.400000
# Principal Data Scientist                 L             202000.000000
# Head of Data                             M             200000.000000
# Director of Data Engineering             L             200000.000000
# Principal Data Engineer                  M             200000.000000
# Research Scientist                       M             192153.000000
# ...

# %%
Avg_salary_for_jobs = pd.DataFrame(df.groupby(['job_title','experience_level','company_size'])['salary_in_usd'].mean())
Avg_salary_for_jobs.sort_values(by=['salary_in_usd'], ascending=False)
# Out:
#                                                                         salary_in_usd
# job_title                                experience_level company_size
# Principal Data Engineer                  EX               L             600000.000000
# Financial Data Analyst                   MI               L             450000.000000
# Principal Data Scientist                 EX               S             416000.000000
# Data Analytics Lead                      SE               L             405000.000000
# Applied Data Scientist                   SE               L             278500.000000
# Lead Data Engineer                       SE               L             276000.000000
# ML Engineer                              MI               L             270000.000000
#                                          SE               S             256000.000000
# Applied Machine Learning Scientist       MI               L             249000.000000
# ...

# %%
sns.barplot(data=df, x='employment_type', y='salary_in_usd')
plt.show()

# %%
df1 = df.drop('s_no', axis=1)

# %%
sns.pairplot(df1)
plt.show()
# Out:
# C:\Users\Aneesfathima\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\Aneesfathima\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\Aneesfathima\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\Aneesfathima\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
